# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests

# Import the API key.
from config import weather_api_key
from config import g_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size = 1500)
lngs = np.random.uniform(-180,180, size = 1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 609

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93e8da1e2881e96791828dd0b6a4443b

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
                city_rain = 0
        
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
                city_snow = 0
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description,
                          "Rain inches":city_rain,
                          "Snow inches":city_snow,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | juchipila
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | semnan
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | nanortalik
# Processing Record 7 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | kushmurun
# Processing Record 11 of Set 1 | seoul
# Processing Record 12 of Set 1 | yeppoon
# Processing Record 13 of Set 1 | salto
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | fukue
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | dafeng
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | marsh harbour
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | olafsvik
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | kichera
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | orumiyeh
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | salalah
# Processing Record 41 of Set 1 | cariati
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | alice springs
# Processing Record 45 of Set 1 | hobyo
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | orlovskiy
# Processing Record 48 of Set 1 | bandarbeyla
# Processing Record 49 of Set 1 | leh
# Processing Record 50 of Set 1 | mackenzie
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | yerbogachen
# Processing Record 3 of Set 2 | muros
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 2 | skagen
# Processing Record 7 of Set 2 | faya
# Processing Record 8 of Set 2 | berdigestyakh
# Processing Record 9 of Set 2 | alyangula
# Processing Record 10 of Set 2 | kruisfontein
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | goderich
# Processing Record 14 of Set 2 | port blair
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | montargis
# Processing Record 18 of Set 2 | morros
# Processing Record 19 of Set 2 | shingu
# Processing Record 20 of Set 2 | srandakan
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | arethousa
# Processing Record 25 of Set 2 | broome
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | katiola
# Processing Record 28 of Set 2 | ayorou
# Processing Record 29 of Set 2 | mana
# Processing Record 30 of Set 2 | kirkenaer
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | hirara
# Processing Record 33 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 2 | lasa
# Processing Record 35 of Set 2 | aneho
# Processing Record 36 of Set 2 | steinbach
# Processing Record 37 of Set 2 | moree
# Processing Record 38 of Set 2 | sassandra
# Processing Record 39 of Set 2 | chicama
# Processing Record 40 of Set 2 | kavaratti
# Processing Record 41 of Set 2 | porto belo
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 2 | beloha
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | poum
# Processing Record 48 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | kununurra
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | glenwood springs
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | bon accord
# Processing Record 5 of Set 3 | denpasar
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | bluefields
# Processing Record 8 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 3 | caravelas
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | san isidro
# Processing Record 14 of Set 3 | saint-augustin
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | kotelnikovo
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | udomlya
# Processing Record 21 of Set 3 | hami
# Processing Record 22 of Set 3 | soure
# Processing Record 23 of Set 3 | may pen
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | redmond
# Processing Record 26 of Set 3 | kysyl-syr
# Processing Record 27 of Set 3 | rochegda
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | tukrah
# Processing Record 31 of Set 3 | morinville
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | nouadhibou
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | placido de castro
# Processing Record 38 of Set 3 | udayagiri
# Processing Record 39 of Set 3 | altay
# Processing Record 40 of Set 3 | matagami
# Processing Record 41 of Set 3 | rajanpur
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | lebedinyy
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | dhidhdhoo
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | honningsvag
# Processing Record 49 of Set 3 | jamestown
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | bondo
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | mamallapuram
# Processing Record 4 of Set 4 | inhambane
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | lerwick
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | pinsk
# Processing Record 13 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 4 | puerto escondido
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | arbazh
# Processing Record 17 of Set 4 | vao
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | zanjan
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | den helder
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | port keats
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | sao felix do xingu
# Processing Record 26 of Set 4 | katha
# City not found. Skipping...
# Processing Record 27 of Set 4 | port alfred
# Processing Record 28 of Set 4 | puerto quijarro
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | buraydah
# Processing Record 31 of Set 4 | srednekolymsk
# Processing Record 32 of Set 4 | batagay
# Processing Record 33 of Set 4 | zhanaozen
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | gizo
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | baghdad
# Processing Record 38 of Set 4 | semarang
# Processing Record 39 of Set 4 | kharhial
# Processing Record 40 of Set 4 | tilichiki
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | mastic beach
# Processing Record 44 of Set 4 | olinda
# Processing Record 45 of Set 4 | scarborough
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | dandeli
# Processing Record 48 of Set 4 | cartagena
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | nalut
# Processing Record 1 of Set 5 | luanda
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | ploufragan
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | corrales
# Processing Record 7 of Set 5 | san quintin
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | tamiahua
# Processing Record 10 of Set 5 | naranjal
# Processing Record 11 of Set 5 | cheremukhovo
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | samarai
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | waingapu
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | kang
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | tignere
# Processing Record 21 of Set 5 | san policarpo
# Processing Record 22 of Set 5 | camacha
# Processing Record 23 of Set 5 | santiago del estero
# Processing Record 24 of Set 5 | diego de almagro
# Processing Record 25 of Set 5 | ahuimanu
# Processing Record 26 of Set 5 | tevriz
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | pevek
# Processing Record 29 of Set 5 | datong
# Processing Record 30 of Set 5 | awbari
# Processing Record 31 of Set 5 | san luis
# Processing Record 32 of Set 5 | hualmay
# Processing Record 33 of Set 5 | tiznit
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | storforshei
# Processing Record 36 of Set 5 | ahipara
# Processing Record 37 of Set 5 | point fortin
# Processing Record 38 of Set 5 | sao jose da coroa grande
# Processing Record 39 of Set 5 | puerto armuelles
# Processing Record 40 of Set 5 | palmer
# Processing Record 41 of Set 5 | mount isa
# Processing Record 42 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 5 | basoko
# Processing Record 44 of Set 5 | bubaque
# Processing Record 45 of Set 5 | kampot
# Processing Record 46 of Set 5 | bangassou
# Processing Record 47 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 5 | hunterville
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | bagan
# Processing Record 1 of Set 6 | rabat
# Processing Record 2 of Set 6 | arica
# Processing Record 3 of Set 6 | sangmelima
# Processing Record 4 of Set 6 | rafraf
# Processing Record 5 of Set 6 | fort nelson
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | barra do corda
# Processing Record 8 of Set 6 | lamar
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | boleslawiec
# Processing Record 11 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 6 | port macquarie
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | khatanga
# Processing Record 15 of Set 6 | lavrentiya
# Processing Record 16 of Set 6 | sitka
# Processing Record 17 of Set 6 | poronaysk
# Processing Record 18 of Set 6 | brae
# Processing Record 19 of Set 6 | ullal
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | karasjok
# Processing Record 22 of Set 6 | klaksvik
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | barreirinha
# Processing Record 25 of Set 6 | chivay
# Processing Record 26 of Set 6 | karup
# Processing Record 27 of Set 6 | fairbanks
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | taos
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | orange cove
# Processing Record 32 of Set 6 | ushtobe
# Processing Record 33 of Set 6 | loei
# Processing Record 34 of Set 6 | ferry pass
# Processing Record 35 of Set 6 | kungurtug
# Processing Record 36 of Set 6 | staroye drozhzhanoye
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | khakhea
# Processing Record 39 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 6 | san marcos
# Processing Record 41 of Set 6 | hovd
# Processing Record 42 of Set 6 | viedma
# Processing Record 43 of Set 6 | lincoln
# Processing Record 44 of Set 6 | dingli
# Processing Record 45 of Set 6 | mumbwa
# Processing Record 46 of Set 6 | vanimo
# Processing Record 47 of Set 6 | hounde
# Processing Record 48 of Set 6 | saskylakh
# Processing Record 49 of Set 6 | broken hill
# Processing Record 50 of Set 6 | terrace
# Processing Record 1 of Set 7 | sarangani
# Processing Record 2 of Set 7 | coahuayana
# Processing Record 3 of Set 7 | podor
# Processing Record 4 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 7 | chuy
# Processing Record 6 of Set 7 | valley city
# Processing Record 7 of Set 7 | victoria
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 7 | gasa
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | inuvik
# Processing Record 13 of Set 7 | alpena
# Processing Record 14 of Set 7 | vardo
# Processing Record 15 of Set 7 | shenzhen
# Processing Record 16 of Set 7 | aksarka
# Processing Record 17 of Set 7 | puerto ayacucho
# Processing Record 18 of Set 7 | waipawa
# Processing Record 19 of Set 7 | cabedelo
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | buala
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | tomohon
# Processing Record 24 of Set 7 | aksarayskiy
# Processing Record 25 of Set 7 | traralgon
# Processing Record 26 of Set 7 | bambous virieux
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | methven
# Processing Record 29 of Set 7 | svetlyy
# Processing Record 30 of Set 7 | diffa
# Processing Record 31 of Set 7 | siwani
# City not found. Skipping...
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | sinnamary
# Processing Record 34 of Set 7 | flinders
# Processing Record 35 of Set 7 | valle de allende
# Processing Record 36 of Set 7 | sakyla
# Processing Record 37 of Set 7 | mar del plata
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | haines junction
# Processing Record 40 of Set 7 | takoradi
# Processing Record 41 of Set 7 | labuan
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | sulangan
# Processing Record 44 of Set 7 | crib point
# Processing Record 45 of Set 7 | paramonga
# Processing Record 46 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 7 | mushie
# Processing Record 48 of Set 7 | hukay
# Processing Record 49 of Set 7 | banepa
# Processing Record 50 of Set 7 | simpang
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | taltal
# Processing Record 3 of Set 8 | kiunga
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | ghazipur
# Processing Record 6 of Set 8 | puerto el triunfo
# Processing Record 7 of Set 8 | mandera
# Processing Record 8 of Set 8 | aykhal
# Processing Record 9 of Set 8 | sibi
# Processing Record 10 of Set 8 | port moresby
# Processing Record 11 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 8 | maragogi
# Processing Record 13 of Set 8 | otavi
# Processing Record 14 of Set 8 | djibo
# Processing Record 15 of Set 8 | dudinka
# Processing Record 16 of Set 8 | kargala
# Processing Record 17 of Set 8 | linqiong
# Processing Record 18 of Set 8 | udachnyy
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | phon
# Processing Record 21 of Set 8 | baruun-urt
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | rodrigues alves
# Processing Record 24 of Set 8 | muisne
# Processing Record 25 of Set 8 | blagoyevo
# Processing Record 26 of Set 8 | halberstadt
# Processing Record 27 of Set 8 | garachine
# Processing Record 28 of Set 8 | klyuchi
# Processing Record 29 of Set 8 | kon tum
# Processing Record 30 of Set 8 | cherskiy
# Processing Record 31 of Set 8 | kismayo
# Processing Record 32 of Set 8 | mirabad
# Processing Record 33 of Set 8 | evensk
# Processing Record 34 of Set 8 | rio cuarto
# Processing Record 35 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 36 of Set 8 | manali
# Processing Record 37 of Set 8 | ostrovnoy
# Processing Record 38 of Set 8 | nome
# Processing Record 39 of Set 8 | svetlaya
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | faanui
# Processing Record 42 of Set 8 | virginia beach
# Processing Record 43 of Set 8 | te anau
# Processing Record 44 of Set 8 | jumla
# Processing Record 45 of Set 8 | zhumadian
# Processing Record 46 of Set 8 | sikasso
# Processing Record 47 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 8 | kangaatsiaq
# Processing Record 49 of Set 8 | victor harbor
# Processing Record 50 of Set 8 | floro
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | flin flon
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | vestmanna
# Processing Record 5 of Set 9 | krasnoselkup
# Processing Record 6 of Set 9 | adra
# Processing Record 7 of Set 9 | zhigansk
# Processing Record 8 of Set 9 | le vauclin
# Processing Record 9 of Set 9 | komsomolskiy
# Processing Record 10 of Set 9 | mahina
# Processing Record 11 of Set 9 | cabo san lucas
# Processing Record 12 of Set 9 | fort frances
# Processing Record 13 of Set 9 | ust-kan
# Processing Record 14 of Set 9 | kambove
# Processing Record 15 of Set 9 | rongcheng
# Processing Record 16 of Set 9 | abha
# Processing Record 17 of Set 9 | krosno odrzanskie
# Processing Record 18 of Set 9 | mahibadhoo
# Processing Record 19 of Set 9 | kerewan
# Processing Record 20 of Set 9 | eastbourne
# Processing Record 21 of Set 9 | qandala
# Processing Record 22 of Set 9 | bardiyah
# Processing Record 23 of Set 9 | pushchino
# Processing Record 24 of Set 9 | maldonado
# Processing Record 25 of Set 9 | arkhangelos
# City not found. Skipping...
# Processing Record 26 of Set 9 | outram
# Processing Record 27 of Set 9 | at-bashi
# Processing Record 28 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 9 | saint-francois
# Processing Record 30 of Set 9 | touba
# Processing Record 31 of Set 9 | shekhupura
# Processing Record 32 of Set 9 | simbakoro
# Processing Record 33 of Set 9 | healdsburg
# Processing Record 34 of Set 9 | bilibino
# Processing Record 35 of Set 9 | lakatoro
# Processing Record 36 of Set 9 | san patricio
# Processing Record 37 of Set 9 | san jose de sisa
# Processing Record 38 of Set 9 | katherine
# Processing Record 39 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 9 | taoudenni
# Processing Record 41 of Set 9 | riyadh
# Processing Record 42 of Set 9 | breves
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | nogales
# Processing Record 45 of Set 9 | merritt
# Processing Record 46 of Set 9 | twin falls
# Processing Record 47 of Set 9 | ayagoz
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | launceston
# Processing Record 50 of Set 9 | turukhansk
# Processing Record 1 of Set 10 | constantine
# Processing Record 2 of Set 10 | vestmannaeyjar
# Processing Record 3 of Set 10 | jasper
# Processing Record 4 of Set 10 | pecos
# Processing Record 5 of Set 10 | abu samrah
# Processing Record 6 of Set 10 | pochutla
# Processing Record 7 of Set 10 | marawi
# Processing Record 8 of Set 10 | meulaboh
# Processing Record 9 of Set 10 | hereford
# Processing Record 10 of Set 10 | bowen
# Processing Record 11 of Set 10 | erdenet
# Processing Record 12 of Set 10 | kralendijk
# Processing Record 13 of Set 10 | havoysund
# Processing Record 14 of Set 10 | valparaiso
# Processing Record 15 of Set 10 | kayerkan
# Processing Record 16 of Set 10 | shache
# Processing Record 17 of Set 10 | beinamar
# Processing Record 18 of Set 10 | college
# Processing Record 19 of Set 10 | axim
# Processing Record 20 of Set 10 | high level
# Processing Record 21 of Set 10 | ormara
# Processing Record 22 of Set 10 | balkanabat
# Processing Record 23 of Set 10 | rawlins
# Processing Record 24 of Set 10 | oshnaviyeh
# Processing Record 25 of Set 10 | rincon
# Processing Record 26 of Set 10 | yarkovo
# Processing Record 27 of Set 10 | touros
# Processing Record 28 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 10 | nurota
# Processing Record 30 of Set 10 | maniitsoq
# Processing Record 31 of Set 10 | beringovskiy
# Processing Record 32 of Set 10 | ashcroft
# Processing Record 33 of Set 10 | ballina
# Processing Record 34 of Set 10 | zhezkazgan
# Processing Record 35 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 10 | sharjah
# Processing Record 37 of Set 10 | hamilton
# Processing Record 38 of Set 10 | gwanda
# Processing Record 39 of Set 10 | giyani
# Processing Record 40 of Set 10 | naron
# Processing Record 41 of Set 10 | bilma
# Processing Record 42 of Set 10 | rawson
# Processing Record 43 of Set 10 | la ronge
# Processing Record 44 of Set 10 | dalvik
# Processing Record 45 of Set 10 | mandalgovi
# Processing Record 46 of Set 10 | tornio
# Processing Record 47 of Set 10 | mashhad
# Processing Record 48 of Set 10 | sabile
# Processing Record 49 of Set 10 | iquique
# Processing Record 50 of Set 10 | tulle
# Processing Record 1 of Set 11 | palatka
# Processing Record 2 of Set 11 | oga
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | raga
# Processing Record 6 of Set 11 | privolzhskiy
# Processing Record 7 of Set 11 | kirensk
# Processing Record 8 of Set 11 | darhan
# Processing Record 9 of Set 11 | marsa matruh
# Processing Record 10 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 11 | charters towers
# Processing Record 12 of Set 11 | pueblo
# Processing Record 13 of Set 11 | live oak
# Processing Record 14 of Set 11 | manitouwadge
# Processing Record 15 of Set 11 | mayumba
# Processing Record 16 of Set 11 | deputatskiy
# Processing Record 17 of Set 11 | cherdyn
# Processing Record 18 of Set 11 | waghai
# Processing Record 19 of Set 11 | poli
# Processing Record 20 of Set 11 | labuhan
# Processing Record 21 of Set 11 | biloela
# Processing Record 22 of Set 11 | biak
# Processing Record 23 of Set 11 | clonakilty
# Processing Record 24 of Set 11 | gladstone
# Processing Record 25 of Set 11 | shiyan
# Processing Record 26 of Set 11 | odweyne
# Processing Record 27 of Set 11 | aguimes
# Processing Record 28 of Set 11 | kulhudhuffushi
# Processing Record 29 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 11 | khash
# Processing Record 31 of Set 11 | nha trang
# Processing Record 32 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 11 | itarema
# Processing Record 34 of Set 11 | portobelo
# Processing Record 35 of Set 11 | tete
# Processing Record 36 of Set 11 | yanam
# Processing Record 37 of Set 11 | bismarck
# Processing Record 38 of Set 11 | kathmandu
# Processing Record 39 of Set 11 | rawah
# Processing Record 40 of Set 11 | brigantine
# Processing Record 41 of Set 11 | san francisco
# Processing Record 42 of Set 11 | jinxi
# Processing Record 43 of Set 11 | cap malheureux
# Processing Record 44 of Set 11 | arman
# Processing Record 45 of Set 11 | sao joao da barra
# Processing Record 46 of Set 11 | aflao
# Processing Record 47 of Set 11 | dongsheng
# Processing Record 48 of Set 11 | mazagao
# Processing Record 49 of Set 11 | visnes
# Processing Record 50 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 12 | dali
# Processing Record 2 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 12 | burica
# City not found. Skipping...
# Processing Record 4 of Set 12 | saint anthony
# Processing Record 5 of Set 12 | sobolevo
# Processing Record 6 of Set 12 | santa cruz de la palma
# Processing Record 7 of Set 12 | hay river
# Processing Record 8 of Set 12 | filadelfia
# Processing Record 9 of Set 12 | casper
# Processing Record 10 of Set 12 | luderitz
# Processing Record 11 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 12 | lompoc
# Processing Record 13 of Set 12 | fort saint james
# Processing Record 14 of Set 12 | tateyama
# Processing Record 15 of Set 12 | colares
# Processing Record 16 of Set 12 | reconquista
# Processing Record 17 of Set 12 | sorland
# Processing Record 18 of Set 12 | tsevie
# Processing Record 19 of Set 12 | souillac
# Processing Record 20 of Set 12 | yurga
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | boyolangu
# Processing Record 23 of Set 12 | bandipur
# Processing Record 24 of Set 12 | sidmouth
# Processing Record 25 of Set 12 | bonthe
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | celestun
# Processing Record 28 of Set 12 | aksu
# Processing Record 29 of Set 12 | abu dhabi
# Processing Record 30 of Set 12 | belmonte
# Processing Record 31 of Set 12 | karratha
# Processing Record 32 of Set 12 | metehara
# City not found. Skipping...
# Processing Record 33 of Set 12 | santa rosa
# Processing Record 34 of Set 12 | noshiro
# Processing Record 35 of Set 12 | nadym
# Processing Record 36 of Set 12 | beyneu
# Processing Record 37 of Set 12 | waw
# Processing Record 38 of Set 12 | nylstroom
# City not found. Skipping...
# Processing Record 39 of Set 12 | andros town
# Processing Record 40 of Set 12 | acapulco
# Processing Record 41 of Set 12 | kutum
# Processing Record 42 of Set 12 | san cristobal
# Processing Record 43 of Set 12 | turka
# Processing Record 44 of Set 12 | naliya
# Processing Record 45 of Set 12 | tabou
# Processing Record 46 of Set 12 | kalianget
# Processing Record 47 of Set 12 | bentiu
# Processing Record 48 of Set 12 | acarau
# Processing Record 49 of Set 12 | korla
# Processing Record 50 of Set 12 | dauriya
# Processing Record 1 of Set 13 | the pas
# Processing Record 2 of Set 13 | tondano
# Processing Record 3 of Set 13 | anadyr
# Processing Record 4 of Set 13 | arcata
# Processing Record 5 of Set 13 | talara
# Processing Record 6 of Set 13 | zilair
# Processing Record 7 of Set 13 | republic
# Processing Record 8 of Set 13 | gagino
# Processing Record 9 of Set 13 | chestermere
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Juchipila  21.42 -103.12     72.27        54          96        4.23
# 1      Semnan  35.57   53.40     76.96        20           7        4.61
# 2    Saldanha -33.01   17.94     84.20        35           0        6.93
# 3    Hermanus -34.42   19.23     71.40        61           0       15.75
# 4  Nanortalik  60.14  -45.24     41.67        69         100        5.23
#
#   Current Description  Rain inches  Snow inches Country                 Date
# 0          light rain            0            0      MX  2020-05-08 14:11:02
# 1           clear sky            0            0      IR  2020-05-08 14:11:02
# 2           clear sky            0            0      ZA  2020-05-08 14:11:03
# 3           clear sky            0            0      ZA  2020-05-08 14:06:34
# 4     overcast clouds            0            0      GL  2020-05-08 14:11:03

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain inches","Snow inches"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0   Juchipila      MX  2020-05-08 14:11:02  21.42 -103.12     72.27        54
# 1      Semnan      IR  2020-05-08 14:11:02  35.57   53.40     76.96        20
# 2    Saldanha      ZA  2020-05-08 14:11:03 -33.01   17.94     84.20        35
# 3    Hermanus      ZA  2020-05-08 14:06:34 -34.42   19.23     71.40        61
# 4  Nanortalik      GL  2020-05-08 14:11:03  60.14  -45.24     41.67        69
# 5      Albany      US  2020-05-08 14:11:03  42.60  -73.97     52.00        27
# 6     Rikitea      PF  2020-05-08 14:11:03 -23.12 -134.97     75.36        72
# 7   Kushmurun      KZ  2020-05-08 14:11:04  52.45   64.63     74.91        30
# 8       Seoul      KR  2020-05-08 14:07:12  37.57  126.98     60.80        87
# 9     Yeppoon      AU  2020-05-08 14:11:04 -23.13  150.73     66.20        82
#
#    Cloudiness  Wind Speed Current Description  Rain inches  Snow inches
# 0          96        4.23          light rain            0            0
# 1           7        4.61           clear sky            0            0
# 2           0        6.93           clear sky            0            0
# 3           0       15.75           clear sky            0            0
# 4         100        5.23     overcast clouds            0            0
# 5         100       11.01     overcast clouds            0            0
# 6          42       11.56    scattered clouds            0            0
# 7           0        9.22           clear sky            0            0
# 8          90        5.82          light rain            0            0
# 9          23        4.70          light rain            0            0

# %%
city_data_df = city_data_df.rename({'Rain inches':'Rain inches (last 3hrs)','Snow inches':'Snow inches (last 3hrs)'},axis=1)
city_data_df.head()
# Out:
#          City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0   Juchipila      MX  2020-05-08 14:11:02  21.42 -103.12     72.27        54
# 1      Semnan      IR  2020-05-08 14:11:02  35.57   53.40     76.96        20
# 2    Saldanha      ZA  2020-05-08 14:11:03 -33.01   17.94     84.20        35
# 3    Hermanus      ZA  2020-05-08 14:06:34 -34.42   19.23     71.40        61
# 4  Nanortalik      GL  2020-05-08 14:11:03  60.14  -45.24     41.67        69
#
#    Cloudiness  Wind Speed Current Description  Rain inches (last 3hrs)  \
# 0          96        4.23          light rain                        0
# 1           7        4.61           clear sky                        0
# 2           0        6.93           clear sky                        0
# 3           0       15.75           clear sky                        0
# 4         100        5.23     overcast clouds                        0
#
#    Snow inches (last 3hrs)
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0

# %%
city_data_df[city_data_df["Rain inches (last 3hrs)"] !=0].count()["Rain inches (last 3hrs)"]
# Out:
# 0

# %%
city_data_df.dtypes
# Out:
# City                        object
# Country                     object
# Date                        object
# Lat                        float64
# Lng                        float64
# Max Temp                   float64
# Humidity                     int64
# Cloudiness                   int64
# Wind Speed                 float64
# Current Description         object
# Rain inches (last 3hrs)      int64
# Snow inches (last 3hrs)      int64
# dtype: object

# %%
city_data_df["Rain inches (last 3hrs)"]=city_data_df["Rain inches (last 3hrs)"].astype(float)
city_data_df["Rain inches (last 3hrs)"]=city_data_df["Rain inches (last 3hrs)"].map("{:.3f}".format)

# %%
city_data_df
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0      Juchipila      MX  2020-05-08 14:11:02  21.42 -103.12     72.27
# 1         Semnan      IR  2020-05-08 14:11:02  35.57   53.40     76.96
# 2       Saldanha      ZA  2020-05-08 14:11:03 -33.01   17.94     84.20
# 3       Hermanus      ZA  2020-05-08 14:06:34 -34.42   19.23     71.40
# 4     Nanortalik      GL  2020-05-08 14:11:03  60.14  -45.24     41.67
# ..           ...     ...                  ...    ...     ...       ...
# 555       Talara      PE  2020-05-08 14:12:43  -4.58  -81.27     78.80
# 556       Zilair      RU  2020-05-08 14:12:43  52.23   57.44     66.60
# 557     Republic      US  2020-05-08 14:12:43  37.12  -93.48     52.00
# 558       Gagino      RU  2020-05-08 14:12:44  55.23   45.03     59.04
# 559  Chestermere      CA  2020-05-08 14:12:44  51.03 -113.82     44.01
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          54          96        4.23          light rain
# 1          20           7        4.61           clear sky
# 2          35           0        6.93           clear sky
# 3          61           0       15.75           clear sky
# 4          69         100        5.23     overcast clouds
# ..        ...         ...         ...                 ...
# 555        57           9       17.22           clear sky
# 556        34           0        7.83           clear sky
# 557        87          90       26.40          light rain
# 558        91         100        3.94          light rain
# 559        87          90       14.99         shower rain
#
#     Rain inches (last 3hrs)  Snow inches (last 3hrs)
# 0                     0.000                        0
# 1                     0.000                        0
# 2                     0.000                        0
# 3                     0.000                        0
# 4                     0.000                        0
# ..                      ...                      ...
# 555                   0.000                        0
# 556                   0.000                        0
# 557                   0.000                        0
# 558                   0.000                        0
# 559                   0.000                        0
#
# [560 rows x 12 columns]

# %%
city_data_df.dtypes
# Out:
# City                        object
# Country                     object
# Date                        object
# Lat                        float64
# Lng                        float64
# Max Temp                   float64
# Humidity                     int64
# Cloudiness                   int64
# Wind Speed                 float64
# Current Description         object
# Rain inches (last 3hrs)     object
# Snow inches (last 3hrs)      int64
# dtype: object

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
